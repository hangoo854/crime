# %%
import pandas as pd

# %%
cctv2017 = pd.read_excel('CCTV_2017.xls')

# %%
cctv2017.head()
# Out:
#     구별    소계  2014년 이전  2015년  2016년 2017년      최근증가율
# 0  강남구  4758      2453    760    770   775  93.966572
# 1  강동구  1493      1101    142    240    10  35.603996
# 2  강북구   946       542    147    257     -  74.538745
# 3  강서구  1202       686    177    168   171  75.218659
# 4  관악구  3223      1917    593    352   361  68.127282

# %%
pop2017 = pd.read_excel('population_2017.xls')
pop2017.head()
# Out:
#     구분     총인구      남자      여자
# 0  종로구  160098   78658   81440
# 1   중구  126104   61645   64459
# 2  용산구  221724  107312  114412
# 3  성동구  301263  148726  152537
# 4  광진구  364924  178445  186479

# %%
pop2017.rename(columns={pop2017.columns[0] : '구별'}, inplace = True)
pop2017.head()
# Out:
#     구별     총인구      남자      여자
# 0  종로구  160098   78658   81440
# 1   중구  126104   61645   64459
# 2  용산구  221724  107312  114412
# 3  성동구  301263  148726  152537
# 4  광진구  364924  178445  186479

# %%
cctv2017.sort_values(by='소계', ascending=True).head()
#cctv의 전체 개수가 가장 작은 구는 '강북구','도봉구','강서구','중랑구','송파구'이다.
# Out:
#      구별    소계  2014년 이전  2015년  2016년 2017년      최근증가율
# 9   도봉구   899       665     49    102    83  35.187970
# 2   강북구   946       542    147    257     -  74.538745
# 24  중랑구  1053       815    102     75    61  29.202454
# 3   강서구  1202       686    177    168   171  75.218659
# 17  송파구  1203       889    124     88   102  35.320585

# %%
cctv2017.sort_values(by='소계', ascending=False).head()
#cctv가 가장 많은 구는 '강남구', '관악구', '용산구', '서대문구' ,'양천구'이다.
# Out:
#       구별    소계  2014년 이전  2015년  2016년 2017년      최근증가율
# 0    강남구  4758      2453    760    770   775  93.966572
# 4    관악구  3223      1917    593    352   361  68.127282
# 6    구로구  2746      1623    256    326   541  69.192853
# 13  서대문구  2705      1922    109    266   408  40.738814
# 15   성동구  2554      2112     98     39   305  20.928030

# %%
pop2017.head()
# Out:
#     구별     총인구      남자      여자
# 0  종로구  160098   78658   81440
# 1   중구  126104   61645   64459
# 2  용산구  221724  107312  114412
# 3  성동구  301263  148726  152537
# 4  광진구  364924  178445  186479

# %%
pop2017['구별'].unique()
# Out:
# array(['종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구', '강북구',
#        '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구', '금천구',
#        '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구'], dtype=object)

# %%
pop2017['여성비율'] = pop2017['여자'] / pop2017['총인구'] * 100
pop2017['남성비율'] = pop2017['남자'] / pop2017['총인구'] * 100
pop2017.head()
# Out:
#     구별     총인구      남자      여자       여성비율       남성비율
# 0  종로구  160098   78658   81440  50.868843  49.131157
# 1   중구  126104   61645   64459  51.115746  48.884254
# 2  용산구  221724  107312  114412  51.601090  48.398910
# 3  성동구  301263  148726  152537  50.632504  49.367496
# 4  광진구  364924  178445  186479  51.100777  48.899223

# %%
pop2017.sort_values(by = '총인구', ascending = False).head()
# 2017년 자치구별 인구수는 '송파구', '강서구', '노원구', 강남구', '관악구' 순으로 인구가 많다.
# Out:
#      구별     총인구      남자      여자       여성비율       남성비율
# 23  송파구  631416  306456  324960  51.465278  48.534722
# 15  강서구  581900  283104  298796  51.348342  48.651658
# 10  노원구  550126  267599  282527  51.356780  48.643220
# 22  강남구  526484  251967  274517  52.141566  47.858434
# 20  관악구  515363  259699  255664  49.608528  50.391472

# %%
merge2017 = pd.merge(cctv2017, pop2017, on='구별')
merge2017.head()
# Out:
#     구별    소계  2014년 이전  2015년  2016년 2017년      최근증가율     총인구      남자      여자  \
# 0  강남구  4758      2453    760    770   775  93.966572  526484  251967  274517
# 1  강동구  1493      1101    142    240    10  35.603996  432865  214557  218308
# 2  강북구   946       542    147    257     -  74.538745  315394  153621  161773
# 3  강서구  1202       686    177    168   171  75.218659  581900  283104  298796
# 4  관악구  3223      1917    593    352   361  68.127282  515363  259699  255664
#
#         여성비율       남성비율
# 0  52.141566  47.858434
# 1  50.433276  49.566724
# 2  51.292352  48.707648
# 3  51.348342  48.651658
# 4  49.608528  50.391472

# %%
merge2017.set_index('구별', inplace=True)
merge2017.head()
#그래프 그릴 것을 생각하면 인덱스 값이 구 이름이 되어야 유리하다.
# Out:
#        소계  2014년 이전  2015년  2016년 2017년      최근증가율     총인구      남자      여자  \
# 구별
# 강남구  4758      2453    760    770   775  93.966572  526484  251967  274517
# 강동구  1493      1101    142    240    10  35.603996  432865  214557  218308
# 강북구   946       542    147    257     -  74.538745  315394  153621  161773
# 강서구  1202       686    177    168   171  75.218659  581900  283104  298796
# 관악구  3223      1917    593    352   361  68.127282  515363  259699  255664
#
#           여성비율       남성비율
# 구별
# 강남구  52.141566  47.858434
# 강동구  50.433276  49.566724
# 강북구  51.292352  48.707648
# 강서구  51.348342  48.651658
# 관악구  49.608528  50.391472

# %%
import numpy as np

# %%
np.corrcoef(merge2017['여성비율'],merge2017['소계'])
#CCTV 개수와 여성비율과의 상관관계 확인 -> 큰 의미가 없다.
# Out:
# array([[ 1.       ,  0.1169676],
#        [ 0.1169676,  1.       ]])

# %%
np.corrcoef(merge2017['남성비율'],merge2017['소계'])
#cctv 개수와 남성비율과의 관계는 큰 의미가 없다고 볼 수 있다.
# Out:
# array([[ 1.       , -0.1169676],
#        [-0.1169676,  1.       ]])

# %%
np.corrcoef(merge2017['총인구'],merge2017['소계'])
#cctv개수와 총인구수의 관계는 큰 의미가 없다.
# Out:
# array([[ 1.        ,  0.19227557],
#        [ 0.19227557,  1.        ]])

# %%
merge2017.sort_values(by = '소계', ascending=False).head()
# Out:
#         소계  2014년 이전  2015년  2016년 2017년      최근증가율     총인구      남자      여자  \
# 구별
# 강남구   4758      2453    760    770   775  93.966572  526484  251967  274517
# 관악구   3223      1917    593    352   361  68.127282  515363  259699  255664
# 구로구   2746      1623    256    326   541  69.192853  436366  218208  218158
# 서대문구  2705      1922    109    266   408  40.738814  317164  151425  165739
# 성동구   2554      2112     98     39   305  20.928030  301263  148726  152537
#
#            여성비율       남성비율
# 구별
# 강남구   52.141566  47.858434
# 관악구   49.608528  50.391472
# 구로구   49.994271  50.005729
# 서대문구  52.256561  47.743439
# 성동구   50.632504  49.367496

# %%
import matplotlib.pyplot as plt
import platform
from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', famaily='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~')
#matplotlib이 기본으로 가진 폰트는 한글을 지원하지 않기 때문에 폰트를 변경할 필요가 있다.

# %%
merge2017.head()
# Out:
#        소계  2014년 이전  2015년  2016년 2017년      최근증가율     총인구      남자      여자  \
# 구별
# 강남구  4758      2453    760    770   775  93.966572  526484  251967  274517
# 강동구  1493      1101    142    240    10  35.603996  432865  214557  218308
# 강북구   946       542    147    257     -  74.538745  315394  153621  161773
# 강서구  1202       686    177    168   171  75.218659  581900  283104  298796
# 관악구  3223      1917    593    352   361  68.127282  515363  259699  255664
#
#           여성비율       남성비율
# 구별
# 강남구  52.141566  47.858434
# 강동구  50.433276  49.566724
# 강북구  51.292352  48.707648
# 강서구  51.348342  48.651658
# 관악구  49.608528  50.391472

# %%
merge2017['소계'].plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %%
merge2017['소계'].sort_values().plot(kind='barh', grid=True, figsize=(10,10))
plt.show()

# %%
merge2017['CCTV비율'] = merge2017['소계'] / merge2017['총인구'] * 100
merge2017['CCTV비율'].sort_values().plot(kind='barh', grid = True, figsize=(10,10))

plt.show()
#인구 대비 CCTV 수를 보면 용산구와 종로구가 높은 것으로 확인 된다.그러나 강서구, 송파구는 인구비로 봐도 CCTV 비율이 낮음을 알 수 있다.

# %%
merge2017.head()
# Out:
#        소계  2014년 이전  2015년  2016년 2017년      최근증가율     총인구      남자      여자  \
# 구별
# 강남구  4758      2453    760    770   775  93.966572  526484  251967  274517
# 강동구  1493      1101    142    240    10  35.603996  432865  214557  218308
# 강북구   946       542    147    257     -  74.538745  315394  153621  161773
# 강서구  1202       686    177    168   171  75.218659  581900  283104  298796
# 관악구  3223      1917    593    352   361  68.127282  515363  259699  255664
#
#           여성비율       남성비율    CCTV비율
# 구별
# 강남구  52.141566  47.858434  0.903731
# 강동구  50.433276  49.566724  0.344911
# 강북구  51.292352  48.707648  0.299942
# 강서구  51.348342  48.651658  0.206565
# 관악구  49.608528  50.391472  0.625384

# %%
plt.figure(figsize=(6,6))
plt.scatter(merge2017['총인구'], merge2017['소계'], s=50) #마커의 크기
plt.xlabel('총인구')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
fp1 = np.polyfit(merge2017['총인구'], merge2017['소계'], 1)
fp1
# Out:
# array([  1.33561344e-03,   1.42558543e+03])

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

# %%
plt.figure(figsize=(10,10))
plt.scatter(merge2017['총인구'], merge2017['소계'], s=50)
plt.plot(fx, f1(fx), ls ='dashed', lw = 3, color='g')
plt.xlabel('총인구')
plt.ylabel('CCTV')
plt.grid()
plt.show()
#x축 데이터는 numpy의 linspave로 만들고, y축은 polyld로 만들 수 있다.

# %%
fp1 = np.polyfit(merge2017['총인구'], merge2017['소계'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

merge2017['오차'] = np.abs(merge2017['소계'] - f1(merge2017['총인구']))

df_sort = merge2017.sort_values(by = '오차', ascending=False)
df_sort.head()
# Out:
#        소계  2014년 이전  2015년  2016년 2017년      최근증가율     총인구      남자      여자  \
# 구별
# 강남구  4758      2453    760    770   775  93.966572  526484  251967  274517
# 관악구  3223      1917    593    352   361  68.127282  515363  259699  255664
# 송파구  1203       889    124     88   102  35.320585  631416  306456  324960
# 강서구  1202       686    177    168   171  75.218659  581900  283104  298796
# 도봉구   899       665     49    102    83  35.187970  334918  163247  171671
#
#           여성비율       남성비율    CCTV비율           오차
# 구별
# 강남구  52.141566  47.858434  0.903731  2629.235468
# 관악구  49.608528  50.391472  0.625384  1109.088825
# 송파구  51.465278  48.534722  0.190524  1065.913122
# 강서구  51.348342  48.651658  0.206565  1000.778886
# 도봉구  51.257621  48.742379  0.268424   973.906408

# %%
plt.figure(figsize=(14,10))
plt.scatter(merge2017['총인구'], merge2017['소계'], c=merge2017['오차'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')

for n in range(10):
    plt.text(df_sort['총인구'][n]*1.02, df_sort['소계'][n]*0.98, df_sort.index[n], fontsize=15)
    
plt.xlabel('총인구')
plt.ylabel('인구당비율')

plt.colorbar()
plt.grid()
plt.show()

# %%
#직선을 기준으로 위에있는 강남구, 관악구, 구로구, 서대문구, 성동구는 서울시 전체 지역의 일반적인 경향보다 CCTV가 많이 서치된 지역이다.
#송파구, 강서구, 중랑구, 도봉구, 강북구는 일반적인 경향보다 CCTV가 적게 설치된 지역이다. 
# 특히, 강남구는 월등히 많은 CCTV가 설치됐지만, 송파구는 인구수에 비해 너무나도 적은 수의 CCTV를 가지고 있다.

# %%
merge2017.to_csv('merge2017.csv', sep=',', encoding='utf-8')
